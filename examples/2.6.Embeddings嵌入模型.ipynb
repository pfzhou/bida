# %% [markdown]
# #### 2.6 Embeddings嵌入模型

# %% [markdown]
# - OpenAI

# %%
from bida import Embedding

em = Embedding(model_type='openai')

result = em.create("hello world")
print(f"返回：{len(result)}个{len(result[0])}维的embedding，内容是：\n{result}")
# Out:
# 返回：1个1536维的embedding，内容是：
# ...

# %%
from bida import Embedding

em = Embedding(model_type='openai')
strlist = ["hello world", "hello china", " ", " \n \n\n", "hello AI"]
result = em.create(strlist)
print(f"返回：{len(result)}个{len(result[0])}维的embedding，内容是：\n{result}")
# Out:
# 返回：3个1536维的embedding，内容是：
# ...

# %% [markdown]
# - 百度 文心一言

# %%
from bida import Embedding

em = Embedding(model_type='baidu')

result = em.create(["hello world"])
print(f"返回：{len(result)}个{len(result[0])}维的embedding，内容是：\n{result}")
# Out:
# 返回：1个384维的embedding，内容是：
# ...

# %%
from bida import Embedding

em = Embedding(model_type='baidu')
strlist = ["hello world", "hello china", " ", " \n \n\n", "hello AI"]
result = em.create(strlist)
print(f"返回：{len(result)}个{len(result[0])}维的embedding，内容是：\n{result}")
# Out:
# 返回：3个384维的embedding，内容是：
# ...

# %% [markdown]
# - 阿里千问

# %%
from bida import Embedding

em = Embedding(model_type='aliyun')

result = em.create(["hello world"])
print(f"返回：{len(result)}个{len(result[0])}维的embedding，内容是：\n{result}")
# Out:
# 返回：1个1536维的embedding，内容是：
# ...

# %%
from bida import Embedding

em = Embedding(model_type='aliyun')
strlist = ["hello world", "hello china", " ", " \n \n\n", "hello AI"]
result = em.create(strlist)
print(f"返回：{len(result)}个{len(result[0])}维的embedding，内容是：\n{result}")
# Out:
# 返回：3个1536维的embedding，内容是：
# ...

# %% [markdown]
# - minimax

# %%
from bida import Embedding

em = Embedding(model_type='minimax')

result = em.create("hello world", embedding_type='db')
print(f"返回：{len(result)}个{len(result[0])}维的embedding，内容是：\n{result}")
# Out:
# 返回：1个1536维的embedding，内容是：
# ...

# %%
from bida import Embedding

em = Embedding(model_type='minimax')

result = em.create("hello world", embedding_type='query')
print(f"返回：{len(result)}个{len(result[0])}维的embedding，内容是：\n{result}")
# Out:
# 返回：1个1536维的embedding，内容是：
# ...

# %%
from bida import Embedding

em = Embedding(model_type='minimax')
strlist = ["hello world", "hello china", " ", " \n \n\n", "hello AI"]
result = em.create(strlist, embedding_type='db')
print(f"返回：{len(result)}个{len(result[0])}维的embedding，内容是：\n{result}")
# Out:
# 返回：3个1536维的embedding，内容是：
# ...

# %%
from bida import Embedding

em = Embedding(model_type='minimax')
strlist = ["hello world", "hello china", " ", " \n \n\n", "hello AI"]
result = em.create(strlist, embedding_type='query')
print(f"返回：{len(result)}个{len(result[0])}维的embedding，内容是：\n{result}")
# Out:
# 返回：3个1536维的embedding，内容是：
# ...

# %% [markdown]
# - 智谱AI-chatglm

# %%
from bida import Embedding

em = Embedding(model_type='chatglm')

result = em.create("hello world")
print(f"返回：{len(result)}个{len(result[0])}维的embedding，内容是：\n{result}")
# Out:
# 返回：1个1024维的embedding，内容是：
# ...

# %%
from bida import Embedding

em = Embedding(model_type='chatglm')
strlist = ["hello world", "hello china", " ", " \n \n\n", "hello AI"]
result = em.create(strlist)
print(f"返回：{len(result)}个{len(result[0])}维的embedding，内容是：\n{result}")
# Out:
# 返回：3个1024维的embedding，内容是：
# ...

# %% [markdown]
# - 讯飞星火大模型

# %%
from bida import Embedding

em = Embedding(model_type='xfyun')

result = em.create("hello world")
print(f"返回：{len(result)}个{len(result[0])}维的embedding，内容是：\n{result}")
# Out:
# 返回：1个1024维的embedding，内容是：
# ...

# %%
from bida import Embedding

em = Embedding(model_type='xfyun')
strlist = ["hello world", "hello china", " ", " \n \n\n", "hello AI"]
result = em.create(strlist)
print(f"返回：{len(result)}个{len(result[0])}维的embedding，内容是：\n{result}")
# Out:
# 返回：3个1024维的embedding，内容是：
# ...
